# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense

# %%
data = pd.read_csv('stock_data.csv')
data.head()
# Out:
#                                                 Text  Sentiment
# 0  Kickers on my watchlist XIDE TIT SOQ PNK CPW B...          1
# 1  user: AAP MOVIE. 55% return for the FEA/GEED i...          1
# 2  user I'd be afraid to short AMZN - they are lo...          1
# 3                                  MNTA Over 12.00            1
# 4                                   OI  Over 21.37            1

# %%
#Split train and test data
X_train, X_test, y_train, y_test = train_test_split(data['Text'], data['Sentiment'], test_size=0.2, random_state=42)

# %%
vectorizer = CountVectorizer()
X_train_vectorized = vectorizer.fit_transform(X_train)
X_test_vectorized = vectorizer.transform(X_test)

nb_classifier = MultinomialNB()
nb_classifier.fit(X_train_vectorized, y_train)

# Predict on the test set
y_pred = nb_classifier.predict(X_test_vectorized)

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Naive Bayes Classifier Accuracy: {accuracy}")
# Out:
# Naive Bayes Classifier Accuracy: 0.7748058671268335

# %%
max_words = 10000
model = Sequential()
model.add(Embedding(max_words, 32, input_length=50))
model.add(LSTM(64))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Tokenize and pad the text data
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

tokenizer = Tokenizer(num_words=max_words)
tokenizer.fit_on_texts(X_train)

X_train_seq = pad_sequences(tokenizer.texts_to_sequences(X_train), maxlen=50)
X_test_seq = pad_sequences(tokenizer.texts_to_sequences(X_test), maxlen=50)

# Train the model
model.fit(X_train_seq, y_train, epochs=20, batch_size=20, validation_split=0.2)

# Evaluate the model on the test set
loss, accuracy = model.evaluate(X_test_seq, y_test)
print(f"TensorFlow NLP Model Accuracy: {accuracy}")
# Out:
# Epoch 1/20
# 186/186 [==============================] - 11s 41ms/step - loss: 0.5325 - accuracy: 0.0483 - val_loss: 0.1749 - val_accuracy: 0.2923
# Epoch 2/20
# 186/186 [==============================] - 8s 45ms/step - loss: -1.2541 - accuracy: 0.4078 - val_loss: -1.3431 - val_accuracy: 0.4035
# Epoch 3/20
# 186/186 [==============================] - 8s 41ms/step - loss: -7.0195 - accuracy: 0.5004 - val_loss: -3.0679 - val_accuracy: 0.4207
# Epoch 4/20
# 186/186 [==============================] - 8s 42ms/step - loss: -12.2681 - accuracy: 0.5414 - val_loss: -3.7830 - val_accuracy: 0.3970
# Epoch 5/20
# 186/186 [==============================] - 8s 43ms/step - loss: -16.8190 - accuracy: 0.5574 - val_loss: -4.4578 - val_accuracy: 0.3581
# Epoch 6/20
# 186/186 [==============================] - 7s 39ms/step - loss: -21.3450 - accuracy: 0.5582 - val_loss: -5.6485 - val_accuracy: 0.3894
# Epoch 7/20
# 186/186 [==============================] - 8s 45ms/step - loss: -26.2890 - accuracy: 0.5671 - val_loss: -6.6828 - val_accuracy: 0.3808
# Epoch 8/20
# 186/186 [==============================] - 7s 39ms/step - loss: -30.6849 - accuracy: 0.5776 - val_loss: -4.5082 - val_accuracy: 0.3560
# Epoch 9/20
# 186/186 [==============================] - 9s 48ms/step - loss: -32.6530 - accuracy: 0.5795 - val_loss: 1.1962 - val_accuracy: 0.5793
# Epoch 10/20
# 186/186 [==============================] - 7s 38ms/step - loss: -31.0309 - accuracy: 0.5798 - val_loss: -8.9892 - val_accuracy: 0.4283
# Epoch 11/20
# 186/186 [==============================] - 9s 48ms/step - loss: -40.4392 - accuracy: 0.5900 - val_loss: -10.6600 - val_accuracy: 0.4196
# Epoch 12/20
# 186/186 [==============================] - 7s 38ms/step - loss: -46.1594 - accuracy: 0.5976 - val_loss: -11.2982 - val_accuracy: 0.4175
# Epoch 13/20
# 186/186 [==============================] - 9s 49ms/step - loss: -43.1811 - accuracy: 0.6054 - val_loss: -2.5180 - val_accuracy: 0.5005
# Epoch 14/20
# 186/186 [==============================] - 7s 37ms/step - loss: -38.4138 - accuracy: 0.5854 - val_loss: -11.7150 - val_accuracy: 0.4045
# Epoch 15/20
# 186/186 [==============================] - 9s 48ms/step - loss: -56.4548 - accuracy: 0.6032 - val_loss: -13.7424 - val_accuracy: 0.4326
# Epoch 16/20
# 186/186 [==============================] - 7s 38ms/step - loss: -62.8896 - accuracy: 0.6100 - val_loss: -13.0227 - val_accuracy: 0.4304
# Epoch 17/20
# 186/186 [==============================] - 9s 46ms/step - loss: -68.3056 - accuracy: 0.6146 - val_loss: -16.3036 - val_accuracy: 0.4315
# Epoch 18/20
# 186/186 [==============================] - 8s 40ms/step - loss: -72.7463 - accuracy: 0.6124 - val_loss: -15.4420 - val_accuracy: 0.4024
# Epoch 19/20
# 186/186 [==============================] - 8s 42ms/step - loss: -78.3477 - accuracy: 0.6181 - val_loss: -18.2136 - val_accuracy: 0.4293
# Epoch 20/20
# 186/186 [==============================] - 8s 42ms/step - loss: -83.4467 - accuracy: 0.6173 - val_loss: -20.0660 - val_accuracy: 0.4358
# 37/37 [==============================] - 1s 16ms/step - loss: -23.8067 - accuracy: 0.4349
# TensorFlow NLP Model Accuracy: 0.43485763669013977
